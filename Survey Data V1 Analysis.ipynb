# %%
#Installing packages
library(data.table)
library(tidyverse)
library(stringi)
library(tidyr)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::between()     masks data.table::between()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ dplyr::first()       masks data.table::first()
# ✖ lubridate::hour()    masks data.table::hour()
# ✖ lubridate::isoweek() masks data.table::isoweek()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ dplyr::last()        masks data.table::last()
# ✖ lubridate::mday()    masks data.table::mday()
# ✖ lubridate::minute()  masks data.table::minute()
# ✖ lubridate::month()   masks data.table::month()
# ✖ lubridate::quarter() masks data.table::quarter()
# ✖ lubridate::second()  masks data.table::second()
# ✖ purrr::transpose()   masks data.table::transpose()
# ✖ lubridate::wday()    masks data.table::wday()
# ✖ lubridate::week()    masks data.table::week()
# ✖ lubridate::yday()    masks data.table::yday()
# ✖ lubridate::year()    masks data.table::year()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
survey_data_original <- read.csv("C:\\Users\\joyse\\Downloads\\comps_subs_conjoint_v2_March+5,+2024_14.01 (1)\\comps_subs_conjoint_v2_March 5, 2024_14.01.csv")
comp_data <-read.csv("C:\\Users\\joyse\\Dropbox (MIT)\\survey\\input_data\\comps_triplets_10p_v1.csv")
sub_data <-read.csv("C:\\Users\\joyse\\Dropbox (MIT)\\survey\\input_data\\subs_triplets_10p_v1.csv")

# %% [markdown]
# # Cleaning Survey Data

# %%
head(survey_data_original)
# Out:
#   StartDate
# 1 Start Date
# 2 {"ImportId":"startDate","timeZone":"America/New_York"}
# 3 2024-02-27 15:17:11
# 4 2024-02-27 15:40:30
# 5 2024-02-27 16:06:21
# 6 2024-02-27 16:06:40
#   EndDate                                              Status
# 1 End Date                                             Response Type
# 2 {"ImportId":"endDate","timeZone":"America/New_York"} {"ImportId":"status"}
# 3 2024-02-27 15:18:15                                  Survey Preview
# 4 2024-02-27 15:41:32                                  Survey Preview
# 5 2024-02-27 16:06:32                                  Survey Preview
# 6 2024-02-27 16:07:03                                  Survey Preview
#   IPAddress                Progress                Duration..in.seconds.
# 1 IP Address               Progress                Duration (in seconds)
# 2 {"ImportId":"ipAddress"} {"ImportId":"progress"} {"ImportId":"duration"}
# 3                          100                     63
# 4                          100                     62
# 5                          100                     11
# 6                          100                     22
#   Finished
# 1 Finished
# 2 {"ImportId":"finished"}
# 3 True
# 4 True
# 5 True
# 6 True
#   RecordedDate
# 1 Recorded Date
# 2 {"ImportId":"recordedDate","timeZone":"America/New_York"}
# 3 2024-02-27 15:18:16
# 4 2024-02-27 15:41:33
# 5 2024-02-27 16:06:33
# 6 2024-02-27 16:07:04
#   ResponseId               RecipientLastName                ⋯
# 1 Response ID              Recipient Last Name              ⋯
# 2 {"ImportId":"_recordId"} {"ImportId":"recipientLastName"} ⋯
# 3 R_1O6ohqQ0k7PbHuS                                         ⋯
# 4 R_1tGbTcv9Opeo7Uw                                         ⋯
# 5 R_1golRVgEoYUAkaE                                         ⋯
# 6 R_138dnQn0uJpiUy1                                         ⋯
#   X1_Q8.1
# 1 Freshburst Listerine Antiseptic Mouthwash For Bad Breath, 1.5 L - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2 {"ImportId":"1_QID6"}
# 3 ${lm://Field/3}
# 4
# 5
# 6
#   X2_Q8.1
# 1 Kashi Heart to Heart Oat Cereal, Organic Blueberry Clusters, 13.4 Oz - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2 {"ImportId":"2_QID6"}
# 3 ${lm://Field/2}
# 4
# 5
# 6
#   X3_Q8.1
# 1 Kleenex Slim Pack Facial Tissues, White, 10 Sheets/Box, 2 Ct - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2 {"ImportId":"3_QID6"}
# 3 ${lm://Field/3}
# 4
# 5
# 6
#   X4_Q8.1
# 1 Folgers Instant Coffee, Classic Roast, 8 Oz, 1 Ct - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2 {"ImportId":"4_QID6"}
# 3 ${lm://Field/3}
# 4
# 5
# 6
#   X5_Q8.1
# 1 Earthborn Holistic Grain-Free Chicken Catcciatori Natural Wet Cat Food, 5.5 Oz - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2 {"ImportId":"5_QID6"}
# 3 ${lm://Field/2}
# 4
# 5
# 6
#   X6_Q8.1
# 1 Hint Water, Watermelon, 16 Fl Oz - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2 {"ImportId":"6_QID6"}
# 3 ${lm://Field/3}
# 4
# 5
# 6
#   X7_Q8.1
# 1 Acana Appalachian Ranch Grain-Free Red Meat & Catfish Dry Dog Food, 25 lb - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2 {"ImportId":"7_QID6"}
# 3 ${lm://Field/2}
# 4
# 5
# 6
#   X8_Q8.1
# 1 Vaseline Baby Petroleum Jelly 13 oz - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2 {"ImportId":"8_QID6"}
# 3 ${lm://Field/3}
# 4
# 5
# 6
#   X9_Q8.1
# 1 McCafÃ© Medium Roast Decaf Ground Coffee, Premium, 12 Oz - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2 {"ImportId":"9_QID6"}
# 3 ${lm://Field/2}
# 4
# 5
# 6
#   X10_Q8.1
# 1 Clarisse Cotton Swabs, Plastic Stick, 375 ct. - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2 {"ImportId":"10_QID6"}
# 3 ${lm://Field/3}
# 4
# 5
# 6

# %%
#Keep only relevant Prolific IDs
survey_data <- survey_data_original[nchar(survey_data$Q1.3) > 10, ]
head(survey_data)
# Out:
#    StartDate
# 1  Start Date
# 2  {"ImportId":"startDate","timeZone":"America/New_York"}
# 13 2024-03-01 19:11:25
# 14 2024-03-01 19:13:58
# 15 2024-03-01 19:13:03
# 16 2024-03-01 19:11:03
#    EndDate                                              Status
# 1  End Date                                             Response Type
# 2  {"ImportId":"endDate","timeZone":"America/New_York"} {"ImportId":"status"}
# 13 2024-03-01 19:15:15                                  IP Address
# 14 2024-03-01 19:16:34                                  IP Address
# 15 2024-03-01 19:19:55                                  IP Address
# 16 2024-03-01 19:19:58                                  IP Address
#    IPAddress                Progress                Duration..in.seconds.
# 1  IP Address               Progress                Duration (in seconds)
# 2  {"ImportId":"ipAddress"} {"ImportId":"progress"} {"ImportId":"duration"}
# 13 84.32.6.206              100                     229
# 14 47.149.78.149            100                     156
# 15 100.1.59.165             100                     412
# 16 73.122.159.161           100                     534
#    Finished
# 1  Finished
# 2  {"ImportId":"finished"}
# 13 True
# 14 True
# 15 True
# 16 True
#    RecordedDate
# 1  Recorded Date
# 2  {"ImportId":"recordedDate","timeZone":"America/New_York"}
# 13 2024-03-01 19:15:16
# 14 2024-03-01 19:16:35
# 15 2024-03-01 19:19:56
# 16 2024-03-01 19:19:58
#    ResponseId               RecipientLastName                ⋯
# 1  Response ID              Recipient Last Name              ⋯
# 2  {"ImportId":"_recordId"} {"ImportId":"recipientLastName"} ⋯
# 13 R_32LGjDD6pWg7YX4                                         ⋯
# 14 R_1kXOK38DO7Y7d60                                         ⋯
# 15 R_5HVMc0NFRQYDgad                                         ⋯
# 16 R_3ZP1VNJfZqbpSov                                         ⋯
#    X1_Q8.1
# 1  Freshburst Listerine Antiseptic Mouthwash For Bad Breath, 1.5 L - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2  {"ImportId":"1_QID6"}
# 13
# 14 ${lm://Field/2}
# 15
# 16 ${lm://Field/2}
#    X2_Q8.1
# 1  Kashi Heart to Heart Oat Cereal, Organic Blueberry Clusters, 13.4 Oz - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2  {"ImportId":"2_QID6"}
# 13
# 14
# 15 ${lm://Field/2}
# 16 ${lm://Field/2}
#    X3_Q8.1
# 1  Kleenex Slim Pack Facial Tissues, White, 10 Sheets/Box, 2 Ct - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2  {"ImportId":"3_QID6"}
# 13 ${lm://Field/2}
# 14 ${lm://Field/3}
# 15 ${lm://Field/3}
# 16
#    X4_Q8.1
# 1  Folgers Instant Coffee, Classic Roast, 8 Oz, 1 Ct - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2  {"ImportId":"4_QID6"}
# 13
# 14 ${lm://Field/2}
# 15 ${lm://Field/2}
# 16
#    X5_Q8.1
# 1  Earthborn Holistic Grain-Free Chicken Catcciatori Natural Wet Cat Food, 5.5 Oz - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2  {"ImportId":"5_QID6"}
# 13
# 14
# 15 ${lm://Field/3}
# 16 ${lm://Field/3}
#    X6_Q8.1
# 1  Hint Water, Watermelon, 16 Fl Oz - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2  {"ImportId":"6_QID6"}
# 13 ${lm://Field/3}
# 14
# 15 ${lm://Field/2}
# 16
#    X7_Q8.1
# 1  Acana Appalachian Ranch Grain-Free Red Meat & Catfish Dry Dog Food, 25 lb - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2  {"ImportId":"7_QID6"}
# 13 ${lm://Field/2}
# 14
# 15
# 16
#    X8_Q8.1
# 1  Vaseline Baby Petroleum Jelly 13 oz - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2  {"ImportId":"8_QID6"}
# 13 ${lm://Field/3}
# 14 ${lm://Field/2}
# 15
# 16
#    X9_Q8.1
# 1  McCafÃ© Medium Roast Decaf Ground Coffee, Premium, 12 Oz - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2  {"ImportId":"9_QID6"}
# 13
# 14 ${lm://Field/3}
# 15
# 16 ${lm://Field/3}
#    X10_Q8.1
# 1  Clarisse Cotton Swabs, Plastic Stick, 375 ct. - If [Field-1] is unavailable, which of the following products would you consider buying instead?
# 2  {"ImportId":"10_QID6"}
# 13 ${lm://Field/2}
# 14
# 15
# 16 ${lm://Field/3}

# %%
cols_to_pivot <- grep("Q5|Q8", names(survey_data), value = TRUE)

# Pivot the dataset from wide to long format
survey_data_filtered <- subset(survey_data, grepl("^R_", ResponseId)) #Only do this for valid respondents

survey_data_long <- pivot_longer(survey_data_filtered, 
                                 cols = cols_to_pivot,       # Columns to pivot
                                 names_to = "Question",      # Name of the column containing question names
                                 values_to = "Question_content" # Name of the column containing response values  
)

#Get rid of rows where the Question wasn't answered by the respondent
survey_data_long <- survey_data_long %>%
                     filter(Question_content != '')


# Print the first few rows of the long format dataset
head(survey_data_long)
# Out:
# Warning message:
# "Using an external vector in selections was deprecated in tidyselect 1.1.0.
# ℹ Please use `all_of()` or `any_of()` instead.
#   # Was:
#   data %>% select(cols_to_pivot)
#
#   # Now:
#   data %>% select(all_of(cols_to_pivot))
#
# See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>."
#   StartDate           EndDate             Status     IPAddress   Progress
# 1 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 2 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 3 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 4 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 5 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 6 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
#   Duration..in.seconds. Finished RecordedDate        ResponseId
# 1 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 2 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 3 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 4 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 5 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 6 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
#   RecipientLastName ⋯
# 1                   ⋯
# 2                   ⋯
# 3                   ⋯
# 4                   ⋯
# 5                   ⋯
# 6                   ⋯
#   Q1.2
# 1 Yes, I would like to take part in this study, and I confirm that I am a US resident, and I am 18 years or older.\n
# 2 Yes, I would like to take part in this study, and I confirm that I am a US resident, and I am 18 years or older.\n
# 3 Yes, I would like to take part in this study, and I confirm that I am a US resident, and I am 18 years or older.\n
# 4 Yes, I would like to take part in this study, and I confirm that I am a US resident, and I am 18 years or older.\n
# 5 Yes, I would like to take part in this study, and I confirm that I am a US resident, and I am 18 years or older.\n
# 6 Yes, I would like to take part in this study, and I confirm that I am a US resident, and I am 18 years or older.\n
#   Q1.3                     Q2.1   Q2.2                      Q2.3
# 1 65e05d49876c66b0a3c18db7 Female Black or African American 45 to 54
# 2 65e05d49876c66b0a3c18db7 Female Black or African American 45 to 54
# 3 65e05d49876c66b0a3c18db7 Female Black or African American 45 to 54
# 4 65e05d49876c66b0a3c18db7 Female Black or African American 45 to 54
# 5 65e05d49876c66b0a3c18db7 Female Black or African American 45 to 54
# 6 65e05d49876c66b0a3c18db7 Female Black or African American 45 to 54
#   Q2.4                                    Q3.2              Q6.2  Question
# 1 Advanced college degree (master's, Phd) Strongly Disagree Agree X3_Q5.1
# 2 Advanced college degree (master's, Phd) Strongly Disagree Agree X5_Q5.1
# 3 Advanced college degree (master's, Phd) Strongly Disagree Agree X7_Q5.1
# 4 Advanced college degree (master's, Phd) Strongly Disagree Agree X8_Q5.1
# 5 Advanced college degree (master's, Phd) Strongly Disagree Agree X10_Q5.1
# 6 Advanced college degree (master's, Phd) Strongly Disagree Agree X3_Q8.1
#   Question_content
# 1 ${lm://Field/2}
# 2 ${lm://Field/2}
# 3 ${lm://Field/2}
# 4 ${lm://Field/3}
# 5 ${lm://Field/3}
# 6 ${lm://Field/2}

# %%
#Create indicators for if the question was a complimentary or substitute question
survey_data_long <- survey_data_long %>%
                     mutate(Comp_question = ifelse(grepl("Q5", Question), 1, 0))
survey_data_long <- survey_data_long %>%
                     mutate(Sub_question = ifelse(grepl("Q8", Question), 1, 0))

head(survey_data_long)
# Out:
#   StartDate           EndDate             Status     IPAddress   Progress
# 1 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 2 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 3 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 4 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 5 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 6 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
#   Duration..in.seconds. Finished RecordedDate        ResponseId
# 1 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 2 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 3 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 4 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 5 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 6 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
#   RecipientLastName ⋯ Q2.1   Q2.2                      Q2.3
# 1                   ⋯ Female Black or African American 45 to 54
# 2                   ⋯ Female Black or African American 45 to 54
# 3                   ⋯ Female Black or African American 45 to 54
# 4                   ⋯ Female Black or African American 45 to 54
# 5                   ⋯ Female Black or African American 45 to 54
# 6                   ⋯ Female Black or African American 45 to 54
#   Q2.4                                    Q3.2              Q6.2  Question
# 1 Advanced college degree (master's, Phd) Strongly Disagree Agree X3_Q5.1
# 2 Advanced college degree (master's, Phd) Strongly Disagree Agree X5_Q5.1
# 3 Advanced college degree (master's, Phd) Strongly Disagree Agree X7_Q5.1
# 4 Advanced college degree (master's, Phd) Strongly Disagree Agree X8_Q5.1
# 5 Advanced college degree (master's, Phd) Strongly Disagree Agree X10_Q5.1
# 6 Advanced college degree (master's, Phd) Strongly Disagree Agree X3_Q8.1
#   Question_content Comp_question Sub_question
# 1 ${lm://Field/2}  1             0
# 2 ${lm://Field/2}  1             0
# 3 ${lm://Field/2}  1             0
# 4 ${lm://Field/3}  1             0
# 5 ${lm://Field/3}  1             0
# 6 ${lm://Field/2}  0             1

# %%
#Create a question_number column for later merging 
survey_data_long <- survey_data_long %>%
                     mutate(Question_Number = as.numeric(str_extract(Question, "(?<=X)\\d+")))


# Print the first few rows of the updated dataset
head(survey_data_long)
# Out:
#   StartDate           EndDate             Status     IPAddress   Progress
# 1 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 2 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 3 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 4 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 5 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
# 6 2024-03-01 19:11:25 2024-03-01 19:15:15 IP Address 84.32.6.206 100
#   Duration..in.seconds. Finished RecordedDate        ResponseId
# 1 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 2 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 3 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 4 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 5 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
# 6 229                   True     2024-03-01 19:15:16 R_32LGjDD6pWg7YX4
#   RecipientLastName ⋯ Q2.2                      Q2.3
# 1                   ⋯ Black or African American 45 to 54
# 2                   ⋯ Black or African American 45 to 54
# 3                   ⋯ Black or African American 45 to 54
# 4                   ⋯ Black or African American 45 to 54
# 5                   ⋯ Black or African American 45 to 54
# 6                   ⋯ Black or African American 45 to 54
#   Q2.4                                    Q3.2              Q6.2  Question
# 1 Advanced college degree (master's, Phd) Strongly Disagree Agree X3_Q5.1
# 2 Advanced college degree (master's, Phd) Strongly Disagree Agree X5_Q5.1
# 3 Advanced college degree (master's, Phd) Strongly Disagree Agree X7_Q5.1
# 4 Advanced college degree (master's, Phd) Strongly Disagree Agree X8_Q5.1
# 5 Advanced college degree (master's, Phd) Strongly Disagree Agree X10_Q5.1
# 6 Advanced college degree (master's, Phd) Strongly Disagree Agree X3_Q8.1
#   Question_content Comp_question Sub_question Question_Number
# 1 ${lm://Field/2}  1             0             3
# 2 ${lm://Field/2}  1             0             5
# 3 ${lm://Field/2}  1             0             7
# 4 ${lm://Field/3}  1             0             8
# 5 ${lm://Field/3}  1             0            10
# 6 ${lm://Field/2}  0             1             3

# %% [markdown]
# # Cleaning Comp and Sub Data

# %%
comp_data <- comp_data %>%
                     mutate(index = row_number())
sub_data <- sub_data %>%
                     mutate(index = row_number())

head(comp_data)
head(sub_data)
# Out:
#   sku_A sku_B cos_sim_B
# 1  165  10594 0.3419732
# 2  502   7403 0.2694587
# 3 1520   5612 0.3317442
# 4 1740  19946 0.2674786
# 5 6215  14839 0.3410132
# 6 6617  19570 0.3718903
#   sku_title_A
# 1 Freshburst Listerine Antiseptic Mouthwash For Bad Breath, 1.5 L
# 2 Kashi Heart to Heart Oat Cereal, Organic Blueberry Clusters, 13.4 Oz
# 3 Kleenex Slim Pack Facial Tissues, White, 10 Sheets/Box, 2 Ct
# 4 Folgers Instant Coffee, Classic Roast, 8 Oz, 1 Ct
# 5 Earthborn Holistic Grain-Free Chicken Catcciatori Natural Wet Cat Food, 5.5 Oz
# 6 Hint Water, Watermelon, 16 Fl Oz
#   l0_A               l1_A                     l2_A
# 1 Health & Beauty    Personal Care            Mouthwash
# 2 Grocery            Breakfast Foods          Cold Cereals
# 3 Household Supplies Paper & Plastic Products Facial Tissues
# 4 Grocery            Beverages                Coffee
# 5 Pet Supplies       Cat Supplies             Cat Food
# 6 Grocery            Beverages                Water
#   sku_title_B
# 1 Gold Bond Ultimate Eczema Relief Skin Protectant Lotion 2%, Colloidal Oatmeal, 14 Oz
# 2 Dr. McDougall's Right Foods Soup, Chili Bean, 18 Ounce
# 3 Seventh Generation Free & Clear Baby Wipes, Flip Top, Unscented, 6 Packs of 64 (384 ct)
# 4 MOLINA VANILLA, EXTRACT VANILLA ORGNL, 8.3 OZ
# 5 Stella & Chewy's Dinner Morsels Grain-Free Chicken Freeze Dried Cat Food, 18 oz
# 6 Firehook Mediterranean Baked Crackers, Garlic & Thyme, 7 Oz
#   l0_B            l1_B                       l2_B              cos_sim_dec_B
# 1 Health & Beauty Skin Care                  Body Moisturizers  1
# 2 Grocery         Soups, Meals & Side Dishes Chilis & Stews     5
# 3 Baby            Diapering                  Baby Wipes         9
# 4 Grocery         Cooking & Baking Supplies  Extracts           3
# 5 Pet Supplies    Cat Supplies               Cat Food           7
# 6 Grocery         Snack Foods                Bread & Crackers  10
#   sku_C cos_sim_C
# 1 33885 0.3681883
# 2  8372 0.2708866
# 3 22414 0.3116748
# 4 27774 0.2790355
# 5 25629 0.3744867
# 6 21267 0.2274641
#   sku_title_C
# 1 Old Spice 2-in-1 Shampoo & Conditioner, Pure Sport, 25.3 Oz
# 2 Pop-Secret Sea Salt Microwaveable Popcorn 6ct 19.2oz
# 3 Clinique Moisture Surge Extra Thirsty Skin Relief, 1.7 Oz
# 4 Double ""Q"" Pink Wild Caught Alaskan Salmon, 14.75 Oz
# 5 Blue Buffalo Healthy Gourmet Ocean Fish & Tuna Pate Recipe Wet Cat Food, 3 Oz
# 6 Laffy Taffy Rope Strawberry, .81 Oz each, 24 Ct
#   l0_C            l1_C                   l2_C
# 1 Health & Beauty Hair Care Products     Shampoos
# 2 Grocery         Snack Foods            Popcorn & Puffed Snacks
# 3 Health & Beauty Skin Care              Facial Moisturizers & Treatments
# 4 Grocery         Canned & Jarred Food   Canned Meat & Seafood
# 5 Pet Supplies    Cat Supplies           Cat Food
# 6 Grocery         Candy, Gum & Chocolate Chewy Candy
#   cos_sim_dec_C index
# 1 4             1
# 2 5             2
# 3 8             3
# 4 4             4
# 5 8             5
# 6 4             6
#   sku_A sku_B cos_sim_B
# 1  165  33321 0.3146814
# 2  502  10274 0.5617551
# 3 1520  15148 0.3108335
# 4 1740   1868 0.6909340
# 5 6215   7849 0.4628579
# 6 6617   7462 0.4637846
#   sku_title_A
# 1 Freshburst Listerine Antiseptic Mouthwash For Bad Breath, 1.5 L
# 2 Kashi Heart to Heart Oat Cereal, Organic Blueberry Clusters, 13.4 Oz
# 3 Kleenex Slim Pack Facial Tissues, White, 10 Sheets/Box, 2 Ct
# 4 Folgers Instant Coffee, Classic Roast, 8 Oz, 1 Ct
# 5 Earthborn Holistic Grain-Free Chicken Catcciatori Natural Wet Cat Food, 5.5 Oz
# 6 Hint Water, Watermelon, 16 Fl Oz
#   l0_A               l1_A                     l2_A
# 1 Health & Beauty    Personal Care            Mouthwash
# 2 Grocery            Breakfast Foods          Cold Cereals
# 3 Household Supplies Paper & Plastic Products Facial Tissues
# 4 Grocery            Beverages                Coffee
# 5 Pet Supplies       Cat Supplies             Cat Food
# 6 Grocery            Beverages                Water
#   sku_title_B
# 1 The Art of Shaving Large Fragrance Gift Set, Oud, 2 Ct (Value of $155)
# 2 Honey Nut Cheerios Cereal, Medley Crunch, 13.1 Oz
# 3 Eucerin Original Moisturizing Lotion, 1 Oz
# 4 Folgers Gourmet Selections Medium Roast Single Serve for Keurig, Classic Roast, 12 Ct
# 5 Purina Friskies Seafood Sensations Dry Cat Food, 16 Lb.
# 6 Dasani Purified Sparkling Water, Strawberry Guava, 12 Fl Oz, 8 Ct
#   l0_B            l1_B            l2_B              cos_sim_dec_B sku_C
# 1 Health & Beauty Fragrance       Men's Fragrance    2            14181
# 2 Grocery         Breakfast Foods Cold Cereals       8            34484
# 3 Health & Beauty Skin Care       Body Moisturizers  6             4620
# 4 Grocery         Beverages       Coffee            10            27088
# 5 Pet Supplies    Cat Supplies    Cat Food           4            16055
# 6 Grocery         Beverages       Water              9             7400
#   cos_sim_C
# 1 0.3428852
# 2 0.3104984
# 3 0.3140773
# 4 0.3721115
# 5 0.6279207
# 6 0.3822151
#   sku_title_C
# 1 Johnson's Buddies No More Tangles Hair Detangler For Kids, 10 Fl. Oz.
# 2 Chilli Man Vegetarian Chili with Beans, 15 oz, (Pack of 12)
# 3 Quilted Northern Ultra Plush Toilet Paper, 24 Double Rolls
# 4 Lipton Mango Unsweetened Iced Tea Mix 10 qt
# 5 Purina Pro Plan FOCUS Adult Indoor Care Salmon & Rice Entree in Sauce Wet Cat Food,  3 Oz. (Pack of 24)
# 6 Lipton Diet Green Tea, Citrus, 16.9 Fl Oz (Innerpack of 12)
#   l0_C               l1_C                       l2_C
# 1 Health & Beauty    Hair Care Products         Styling Products
# 2 Grocery            Soups, Meals & Side Dishes Chilis & Stews
# 3 Household Supplies Paper & Plastic Products   Toilet Paper
# 4 Grocery            Beverages                  Drink Mixes & Syrups
# 5 Pet Supplies       Cat Supplies               Cat Food
# 6 Grocery            Beverages                  Tea
#   cos_sim_dec_C index
# 1 5             1
# 2 2             2
# 3 6             3
# 4 5             4
# 5 8             5
# 6 8             6

# %% [markdown]
# # Merging Comp and Sub Data with Survey Data

# %%
#Merge comp_data with survey_long
merged_data <- merge(survey_data_long,comp_data, by.x = "Question_Number", by.y = "index", all.x = TRUE)

#Sorting by response ID
merged_data <- merged_data %>% arrange(ResponseId)

#Adding prefix of comp to all columns from comp_data
comp_columns <- names(merged_data)[names(merged_data) %in% names(comp_data)]
names(merged_data)[names(merged_data) %in% comp_columns] <- paste0("comp_", comp_columns)


# Print the merged dataset
head(merged_data)
# Out:
#   Question_Number StartDate           EndDate             Status
# 1 1               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 2 2               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 3 2               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 4 3               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 5 5               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 6 6               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
#   IPAddress    Progress Duration..in.seconds. Finished RecordedDate
# 1 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 2 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 3 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 4 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 5 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 6 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
#   ResponseId        ⋯ comp_l1_B                  comp_l2_B
# 1 R_13lazkKZyyvoIwx ⋯ Skin Care                  Body Moisturizers
# 2 R_13lazkKZyyvoIwx ⋯ Soups, Meals & Side Dishes Chilis & Stews
# 3 R_13lazkKZyyvoIwx ⋯ Soups, Meals & Side Dishes Chilis & Stews
# 4 R_13lazkKZyyvoIwx ⋯ Diapering                  Baby Wipes
# 5 R_13lazkKZyyvoIwx ⋯ Cat Supplies               Cat Food
# 6 R_13lazkKZyyvoIwx ⋯ Snack Foods                Bread & Crackers
#   comp_cos_sim_dec_B comp_sku_C comp_cos_sim_C
# 1  1                 33885      0.3681883
# 2  5                  8372      0.2708866
# 3  5                  8372      0.2708866
# 4  9                 22414      0.3116748
# 5  7                 25629      0.3744867
# 6 10                 21267      0.2274641
#   comp_sku_title_C
# 1 Old Spice 2-in-1 Shampoo & Conditioner, Pure Sport, 25.3 Oz
# 2 Pop-Secret Sea Salt Microwaveable Popcorn 6ct 19.2oz
# 3 Pop-Secret Sea Salt Microwaveable Popcorn 6ct 19.2oz
# 4 Clinique Moisture Surge Extra Thirsty Skin Relief, 1.7 Oz
# 5 Blue Buffalo Healthy Gourmet Ocean Fish & Tuna Pate Recipe Wet Cat Food, 3 Oz
# 6 Laffy Taffy Rope Strawberry, .81 Oz each, 24 Ct
#   comp_l0_C       comp_l1_C              comp_l2_C
# 1 Health & Beauty Hair Care Products     Shampoos
# 2 Grocery         Snack Foods            Popcorn & Puffed Snacks
# 3 Grocery         Snack Foods            Popcorn & Puffed Snacks
# 4 Health & Beauty Skin Care              Facial Moisturizers & Treatments
# 5 Pet Supplies    Cat Supplies           Cat Food
# 6 Grocery         Candy, Gum & Chocolate Chewy Candy
#   comp_cos_sim_dec_C
# 1 4
# 2 5
# 3 5
# 4 8
# 5 8
# 6 4

# %%
#Merge sub_data with merged_data
merged_data <- merge(merged_data,sub_data, by.x = "Question_Number", by.y = "index", all.x = TRUE)

#Sorting by response ID
merged_data <- merged_data %>% arrange(ResponseId, Sub_question)

#Adding a prefix of sub to all columns from sub data
sub_columns <- names(merged_data)[names(merged_data) %in% names(sub_data)]
names(merged_data)[names(merged_data) %in% sub_columns] <- paste0("sub_", sub_columns)


# Print the merged dataset
head(merged_data)
#At this point, all of the data is merged
# Out:
#   Question_Number StartDate           EndDate             Status
# 1 1               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 2 2               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 3 3               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 4 5               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 5 8               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 6 2               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
#   IPAddress    Progress Duration..in.seconds. Finished RecordedDate
# 1 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 2 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 3 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 4 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 5 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 6 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
#   ResponseId        ⋯ sub_l1_B        sub_l2_B          sub_cos_sim_dec_B
# 1 R_13lazkKZyyvoIwx ⋯ Fragrance       Men's Fragrance   2
# 2 R_13lazkKZyyvoIwx ⋯ Breakfast Foods Cold Cereals      8
# 3 R_13lazkKZyyvoIwx ⋯ Skin Care       Body Moisturizers 6
# 4 R_13lazkKZyyvoIwx ⋯ Cat Supplies    Cat Food          4
# 5 R_13lazkKZyyvoIwx ⋯ Skin Care       Lip Care          7
# 6 R_13lazkKZyyvoIwx ⋯ Breakfast Foods Cold Cereals      8
#   sub_sku_C sub_cos_sim_C
# 1 14181     0.3428852
# 2 34484     0.3104984
# 3  4620     0.3140773
# 4 16055     0.6279207
# 5 16255     0.4232357
# 6 34484     0.3104984
#   sub_sku_title_C
# 1 Johnson's Buddies No More Tangles Hair Detangler For Kids, 10 Fl. Oz.
# 2 Chilli Man Vegetarian Chili with Beans, 15 oz, (Pack of 12)
# 3 Quilted Northern Ultra Plush Toilet Paper, 24 Double Rolls
# 4 Purina Pro Plan FOCUS Adult Indoor Care Salmon & Rice Entree in Sauce Wet Cat Food,  3 Oz. (Pack of 24)
# 5 Zoe Organics Nipple Balm, 2 Oz
# 6 Chilli Man Vegetarian Chili with Beans, 15 oz, (Pack of 12)
#   sub_l0_C           sub_l1_C                   sub_l2_C
# 1 Health & Beauty    Hair Care Products         Styling Products
# 2 Grocery            Soups, Meals & Side Dishes Chilis & Stews
# 3 Household Supplies Paper & Plastic Products   Toilet Paper
# 4 Pet Supplies       Cat Supplies               Cat Food
# 5 Health & Beauty    Skin Care                  Body Moisturizers
# 6 Grocery            Soups, Meals & Side Dishes Chilis & Stews
#   sub_cos_sim_dec_C
# 1 5
# 2 2
# 3 6
# 4 8
# 5 9
# 6 2

# %% [markdown]
# # Creating Result Columns

# %%
#Create cos_sim_dif column that measures the cos_sim_dif between product B-product C, depending on comp or sub
merged_data$cos_sim_dif <- ifelse(merged_data$Comp_question == 1, 
                                  merged_data$comp_cos_sim_B - merged_data$comp_cos_sim_C,
                                  merged_data$sub_cos_sim_B - merged_data$sub_cos_sim_C)

# Print the first few rows of the updated dataset
head(merged_data["Question"])
head(merged_data)
# Out:
#   Question
# 1 X1_Q5.1
# 2 X2_Q5.1
# 3 X3_Q5.1
# 4 X5_Q5.1
# 5 X8_Q5.1
# 6 X2_Q8.1
#   Question_Number StartDate           EndDate             Status
# 1 1               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 2 2               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 3 3               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 4 5               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 5 8               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 6 2               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
#   IPAddress    Progress Duration..in.seconds. Finished RecordedDate
# 1 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 2 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 3 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 4 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 5 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 6 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
#   ResponseId        ⋯ sub_l2_B          sub_cos_sim_dec_B sub_sku_C
# 1 R_13lazkKZyyvoIwx ⋯ Men's Fragrance   2                 14181
# 2 R_13lazkKZyyvoIwx ⋯ Cold Cereals      8                 34484
# 3 R_13lazkKZyyvoIwx ⋯ Body Moisturizers 6                  4620
# 4 R_13lazkKZyyvoIwx ⋯ Cat Food          4                 16055
# 5 R_13lazkKZyyvoIwx ⋯ Lip Care          7                 16255
# 6 R_13lazkKZyyvoIwx ⋯ Cold Cereals      8                 34484
#   sub_cos_sim_C
# 1 0.3428852
# 2 0.3104984
# 3 0.3140773
# 4 0.6279207
# 5 0.4232357
# 6 0.3104984
#   sub_sku_title_C
# 1 Johnson's Buddies No More Tangles Hair Detangler For Kids, 10 Fl. Oz.
# 2 Chilli Man Vegetarian Chili with Beans, 15 oz, (Pack of 12)
# 3 Quilted Northern Ultra Plush Toilet Paper, 24 Double Rolls
# 4 Purina Pro Plan FOCUS Adult Indoor Care Salmon & Rice Entree in Sauce Wet Cat Food,  3 Oz. (Pack of 24)
# 5 Zoe Organics Nipple Balm, 2 Oz
# 6 Chilli Man Vegetarian Chili with Beans, 15 oz, (Pack of 12)
#   sub_l0_C           sub_l1_C                   sub_l2_C
# 1 Health & Beauty    Hair Care Products         Styling Products
# 2 Grocery            Soups, Meals & Side Dishes Chilis & Stews
# 3 Household Supplies Paper & Plastic Products   Toilet Paper
# 4 Pet Supplies       Cat Supplies               Cat Food
# 5 Health & Beauty    Skin Care                  Body Moisturizers
# 6 Grocery            Soups, Meals & Side Dishes Chilis & Stews
#   sub_cos_sim_dec_C cos_sim_dif
# 1 5                 -0.026215151
# 2 2                 -0.001427876
# 3 6                  0.020069370
# 4 8                 -0.033473509
# 5 9                 -0.029594200
# 6 2                  0.251256713

# %%
#Create cos_sim_bin that is 1 if the cos_sim score of Product B is greater than Product C, 0 otherwise 
merged_data$cos_sim_bin <- ifelse(merged_data$cos_sim_dif >= 0, 1, 0)

# Print the first few rows of the updated dataset
head(merged_data)
# Out:
#   Question_Number StartDate           EndDate             Status
# 1 1               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 2 2               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 3 3               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 4 5               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 5 8               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 6 2               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
#   IPAddress    Progress Duration..in.seconds. Finished RecordedDate
# 1 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 2 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 3 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 4 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 5 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 6 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
#   ResponseId        ⋯ sub_cos_sim_dec_B sub_sku_C sub_cos_sim_C
# 1 R_13lazkKZyyvoIwx ⋯ 2                 14181     0.3428852
# 2 R_13lazkKZyyvoIwx ⋯ 8                 34484     0.3104984
# 3 R_13lazkKZyyvoIwx ⋯ 6                  4620     0.3140773
# 4 R_13lazkKZyyvoIwx ⋯ 4                 16055     0.6279207
# 5 R_13lazkKZyyvoIwx ⋯ 7                 16255     0.4232357
# 6 R_13lazkKZyyvoIwx ⋯ 8                 34484     0.3104984
#   sub_sku_title_C
# 1 Johnson's Buddies No More Tangles Hair Detangler For Kids, 10 Fl. Oz.
# 2 Chilli Man Vegetarian Chili with Beans, 15 oz, (Pack of 12)
# 3 Quilted Northern Ultra Plush Toilet Paper, 24 Double Rolls
# 4 Purina Pro Plan FOCUS Adult Indoor Care Salmon & Rice Entree in Sauce Wet Cat Food,  3 Oz. (Pack of 24)
# 5 Zoe Organics Nipple Balm, 2 Oz
# 6 Chilli Man Vegetarian Chili with Beans, 15 oz, (Pack of 12)
#   sub_l0_C           sub_l1_C                   sub_l2_C
# 1 Health & Beauty    Hair Care Products         Styling Products
# 2 Grocery            Soups, Meals & Side Dishes Chilis & Stews
# 3 Household Supplies Paper & Plastic Products   Toilet Paper
# 4 Pet Supplies       Cat Supplies               Cat Food
# 5 Health & Beauty    Skin Care                  Body Moisturizers
# 6 Grocery            Soups, Meals & Side Dishes Chilis & Stews
#   sub_cos_sim_dec_C cos_sim_dif  cos_sim_bin
# 1 5                 -0.026215151 0
# 2 2                 -0.001427876 0
# 3 6                  0.020069370 1
# 4 8                 -0.033473509 0
# 5 9                 -0.029594200 0
# 6 2                  0.251256713 1

# %%
#Create the Choice column based on the conditions, 1 if choose correctly, 0 otherwise
merged_data$Choice <- ifelse(merged_data$Question_content == '${lm://Field/2}' & merged_data$cos_sim_bin == 1, 1,
                             ifelse(merged_data$Question_content == '${lm://Field/3}' & merged_data$cos_sim_bin == 0, 1,
                                    0))

# Print the first few rows of the updated dataset
head(merged_data)
# Out:
#   Question_Number StartDate           EndDate             Status
# 1 1               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 2 2               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 3 3               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 4 5               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 5 8               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
# 6 2               2024-03-01 19:51:46 2024-03-01 20:15:45 IP Address
#   IPAddress    Progress Duration..in.seconds. Finished RecordedDate
# 1 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 2 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 3 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 4 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 5 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
# 6 97.87.61.137 100      1439                  True     2024-03-01 20:15:45
#   ResponseId        ⋯ sub_sku_C sub_cos_sim_C
# 1 R_13lazkKZyyvoIwx ⋯ 14181     0.3428852
# 2 R_13lazkKZyyvoIwx ⋯ 34484     0.3104984
# 3 R_13lazkKZyyvoIwx ⋯  4620     0.3140773
# 4 R_13lazkKZyyvoIwx ⋯ 16055     0.6279207
# 5 R_13lazkKZyyvoIwx ⋯ 16255     0.4232357
# 6 R_13lazkKZyyvoIwx ⋯ 34484     0.3104984
#   sub_sku_title_C
# 1 Johnson's Buddies No More Tangles Hair Detangler For Kids, 10 Fl. Oz.
# 2 Chilli Man Vegetarian Chili with Beans, 15 oz, (Pack of 12)
# 3 Quilted Northern Ultra Plush Toilet Paper, 24 Double Rolls
# 4 Purina Pro Plan FOCUS Adult Indoor Care Salmon & Rice Entree in Sauce Wet Cat Food,  3 Oz. (Pack of 24)
# 5 Zoe Organics Nipple Balm, 2 Oz
# 6 Chilli Man Vegetarian Chili with Beans, 15 oz, (Pack of 12)
#   sub_l0_C           sub_l1_C                   sub_l2_C
# 1 Health & Beauty    Hair Care Products         Styling Products
# 2 Grocery            Soups, Meals & Side Dishes Chilis & Stews
# 3 Household Supplies Paper & Plastic Products   Toilet Paper
# 4 Pet Supplies       Cat Supplies               Cat Food
# 5 Health & Beauty    Skin Care                  Body Moisturizers
# 6 Grocery            Soups, Meals & Side Dishes Chilis & Stews
#   sub_cos_sim_dec_C cos_sim_dif  cos_sim_bin Choice
# 1 5                 -0.026215151 0           0
# 2 2                 -0.001427876 0           0
# 3 6                  0.020069370 1           1
# 4 8                 -0.033473509 0           1
# 5 9                 -0.029594200 0           1
# 6 2                  0.251256713 1           1

# %%
#Export as CSV
write.csv(merged_data, file = "C:\\Users\\joyse\\Desktop\\UROP\\merged_data_v1.csv", row.names = FALSE)

# %% [markdown]
# # Results

# %%
#Overall average correct
cat("Overall proportion of correct answers:", mean(merged_data$Choice), "\n")
cat("Average cos_sim_dif overall:", mean(merged_data$cos_sim_dif), "\n")
# Out:
# Overall proportion of correct answers: 0.655
# Average cos_sim_dif overall: -0.00411533

# %%
#Get the proportion of correct choices for comp questions
subset_data_c <- subset(merged_data, Comp_question == 1)

mean_choice <- mean(subset_data_c$Choice)
std_dev_choice <- sd(subset_data_c$Choice)

# Print average cos_sim_dif
cat("Average cos_sim_dif for compliments:", mean(subset_data_c$cos_sim_dif), "\n")

# Print proportion of correct answers
cat("Proportion of correct answers for compliment question:", mean_choice, "\n")

# Print standard deviation of correct answers
cat("Standard deviation of correct answers for compliment question:", std_dev_choice, "\n")

# Perform one-sample t-test
test_result <- t.test(subset_data_c$Choice, mu = 0.5)

# Print the test result
cat("Significance test result for proportion of correct answers:\n")
print(test_result)
# Out:
# Average cos_sim_dif for compliments: 0.01905805
# Proportion of correct answers for compliment question: 0.54
# Standard deviation of correct answers for compliment question: 0.5009083
# Significance test result for proportion of correct answers:
#
# 	One Sample t-test
#
# data:  subset_data_c$Choice
# t = 0.79855, df = 99, p-value = 0.4265
# alternative hypothesis: true mean is not equal to 0.5
# 95 percent confidence interval:
#  0.4406089 0.6393911
# sample estimates:
# mean of x
#      0.54

# %%
#Get the proportion of correct choices for sub questions
subset_data_s <- subset(merged_data, Sub_question == 1)

mean_choice <- mean(subset_data_s$Choice)
std_dev_choice <- sd(subset_data_s$Choice)

#Average cos_sim_dif for substitutes
cat("Average cos_sim_dif for substitutes:", mean(subset_data_s$cos_sim_dif), "\n")

# Print proportion of correct answers
cat("Proportion of correct answers for substitute question:", mean_choice, "\n")

# Print standard deviation of correct answers
cat("Standard deviation of correct answers for substitute question:", std_dev_choice, "\n")

# Perform one-sample t-test
test_result <- t.test(subset_data_s$Choice, mu = 0.5)

# Print the test result
cat("Significance test result for proportion of correct answers:\n")
print(test_result)
# Out:
# Average cos_sim_dif for substitutes: -0.02728871
# Proportion of correct answers for substitute question: 0.77
# Standard deviation of correct answers for substitute question: 0.4229526
# Significance test result for proportion of correct answers:
#
# 	One Sample t-test
#
# data:  subset_data_s$Choice
# t = 6.3837, df = 99, p-value = 5.617e-09
# alternative hypothesis: true mean is not equal to 0.5
# 95 percent confidence interval:
#  0.686077 0.853923
# sample estimates:
# mean of x
#      0.77

# %%
#Regression on cos_sim_dif
lm_model <- lm(Choice ~ cos_sim_dif, data = merged_data)

# Print the summary of the regression model
summary(lm_model)
# Out:
# Call:
# lm(formula = Choice ~ cos_sim_dif, data = merged_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.6560 -0.6548  0.3444  0.3452  0.3488
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.655029   0.033794  19.383   <2e-16 ***
# cos_sim_dif 0.007016   0.213885   0.033    0.974
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.4778 on 198 degrees of freedom
# Multiple R-squared:  5.434e-06,	Adjusted R-squared:  -0.005045
# F-statistic: 0.001076 on 1 and 198 DF,  p-value: 0.9739

# %%
#Regression on cos_sim_bin
lm_model <- lm(Choice ~ cos_sim_bin, data = merged_data)

# Print the summary of the regression model
summary(lm_model)
# Out:
# Call:
# lm(formula = Choice ~ cos_sim_bin, data = merged_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.6610 -0.6463  0.3390  0.3537  0.3537
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.66102    0.04398  15.031   <2e-16 ***
# cos_sim_bin -0.01468    0.06868  -0.214    0.831
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.4777 on 198 degrees of freedom
# Multiple R-squared:  0.0002305,	Adjusted R-squared:  -0.004819
# F-statistic: 0.04566 on 1 and 198 DF,  p-value: 0.831
